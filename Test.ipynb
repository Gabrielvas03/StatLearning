# %% [markdown]
# # 2.3 Lab: Introduction to Python

# %% [markdown]
# ## Introduction to Numerical Python

# %%
import numpy as np

# %%
x = np.array([3,4,5])
y = np.array([4,9,7])

x + y
# Out:
# array([ 7, 13, 12])

# %%
x = np.array([[1,2,3], [4,5,6]])
x
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
x.shape
# Out:
# (2, 3)

# %%
x = np.random.normal(size = 50)
x
# Out:
# array([-0.79934174,  1.69562518, -0.10206553,  0.28062708, -1.30843198,
#        -1.67725924, -0.20060839, -0.79201235, -0.00396051, -3.45571645,
#        -0.43052314, -0.03186376, -1.23000376, -0.32055452,  0.76737474,
#         0.92679279, -0.32003723,  0.19813102, -1.16144655, -0.10854109,
#         0.10389417, -0.43127716,  1.20131663,  0.62016215,  0.82038939,
#         0.68496308,  0.0955105 ,  1.06796121,  1.44806203, -0.11665237,
#        -0.52044555,  1.2018998 ,  0.61448604, -0.74930611,  0.33710592,
#         0.26137636,  2.31220884,  0.33179958, -1.08950638, -1.83939989,
#        -1.04446505, -0.75413329,  0.9694722 ,  0.77216025, -1.35688917,
#        -0.39779106,  0.08570715, -1.10946541, -0.50947119, -1.91440564])

# %%
y = x + np.random.normal(loc =5, scale = 1, size = 50)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.       , 0.7977265],
#        [0.7977265, 1.       ]])

# %%
from matplotlib.pyplot import subplots
fig, ax = subplots(figsize = (8,8))
x = np.random.normal(size = 100)
y = np.random.normal(size = 100)
ax.scatter(x,y, marker = "o");
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("Scatterplot of x vs y")
plt.show()
